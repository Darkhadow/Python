# %%
import pandas as pd

pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
pd.set_option('display.width',None)

# %%
pkm_df = pd.read_csv("Pokemon_Gen_1-8.csv")

# %%
pkm_df

# %%
pkm_df.shape

# %%
pkm_df.size

# %%
pkm_df.shape[0] * pkm_df.shape[1]

# %%
pkm_names = pkm_df['Name']
pkm_names.head()

# %%
type(pkm_names)

# %%
pkm_types = pkm_df[['Name', 'Type 1', 'Type 2']]
pkm_types.head()

# %%
pkm_atkdef = pkm_df[pkm_df.columns[5:7]]
pkm_atkdef.head()

# %%
pkm_df.columns[5:7]

# %%
pkm_values = pkm_df.loc[28:100,['Name','Average','Total']]
pkm_values.tail()

# %%
columns_name = []
ask=input("How many columns do you wang?(Type 1 number bellow the num that yuo wang to tpye out) ")
ask3=input("How many rowssss do you wang? ")
for i in range(int(ask)):
    ask2=input("What do you wang your colmuns names to be? ")
    columns_name.append(ask2)
columns_name
pkm_values = pkm_df.loc[0:ask3,[columns_name]]

# %%
import pandas as pd

pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
pd.set_option('display.width',None)

# %%
pkm_df = pd.read_csv("Pokemon_Gen_1-8.csv")

# %%
pkm_df1 = pkm_df.rename(columns = {'Average':'AVG','Generation':'GEN'})

# %%
pkm_df1.head()
# Out:
#    #                      Name Type 1  Type 2  HP  Attack  Defense  \
# 0  1                 Bulbasaur  Grass  Poison  45      49       49
# 1  2                   Ivysaur  Grass  Poison  60      62       63
# 2  3                  Venusaur  Grass  Poison  80      82       83
# 3  3  Venusaur (Mega Venusaur)  Grass  Poison  80     100      123
# 4  4                Charmander   Fire     NaN  39      52       43
#
#    Sp. Attack  Sp. Defense  Speed  Total     AVG  GEN
# 0          65           65     45    318   53.00    1
# 1          80           80     60    405   67.50    1
# 2         100          100     80    525   87.50    1
# 3         122          120     80    625  104.17    1
# 4          60           50     65    309   51.50    1

# %%
pkm_df2 = pkm_df[['Name','Type 1','Type 2']]
pkm_df2.columns = ['Name','Main Type','Sub Type']
pkm_df2.head(3)
# Out:
#         Name Main Type Sub Type
# 0  Bulbasaur     Grass   Poison
# 1    Ivysaur     Grass   Poison
# 2   Venusaur     Grass   Poison

# %%
test1 = pkm_df[pkm_df.Name == 'Pikachu']
test1
# Out:
#      #     Name  Type 1 Type 2  HP  Attack  Defense  Sp. Attack  Sp. Defense  \
# 32  25  Pikachu  Ground    NaN  35      55       40          50           50
#
#     Speed  Total  Average  Generation
# 32     90    320    53.33           1

# %%
grp_fire = pkm_df2[pkm_df2['Main Type'] == 'Fire']
print(grp_fire.shape)
grp_fire
# Out:
# (65, 3)
#                              Name Main Type  Sub Type
# 4                      Charmander      Fire       NaN
# 5                      Charmeleon      Fire       NaN
# 6                       Charizard      Fire    Flying
# 7    Charizard (Mega Charizard X)      Fire    Dragon
# 8    Charizard (Mega Charizard Y)      Fire    Flying
# 42                      Nidoqueen      Fire       NaN
# 43                       Nidoran♂      Fire       NaN
# 63                        Diglett      Fire       NaN
# 64       Diglett (Alolan Diglett)      Fire       NaN
# 83                       Alakazam      Fire       NaN
# 84       Alakazam (Mega Alakazam)      Fire       NaN
# 135                       Marowak      Fire       NaN
# 147                    Kangaskhan      Fire       NaN
# 158                          Jynx      Fire    Flying
# 169                         Eevee      Fire       NaN
# 170         Eevee (Partner Eevee)      Fire       NaN
# ...

# %%
grp_water = pkm_df2[pkm_df2['Main Type'] == 'Water']
print(grp_water.shape)
grp_water
# Out:
# (133, 3)
#                             Name Main Type  Sub Type
# 9                       Squirtle     Water       NaN
# 10                     Wartortle     Water       NaN
# 11                     Blastoise     Water       NaN
# 12    Blastoise (Mega Blastoise)     Water       NaN
# 59                         Paras     Water       NaN
# 60                      Parasect     Water       NaN
# 65                       Dugtrio     Water       NaN
# 66      Dugtrio (Alolan Dugtrio)     Water       NaN
# 67                        Meowth     Water  Fighting
# 78                       Poliwag     Water    Poison
# 79                     Poliwhirl     Water    Poison
# 85                        Machop     Water   Psychic
# 86                       Machoke     Water   Psychic
# 87                       Machamp     Water   Psychic
# 93                       Geodude     Water       NaN
# 94      Geodude (Alolan Geodude)     Water       Ice
# ...

# %%
grp_fireWater = grp_fire.append(grp_water)
print(grp_fireWater.shape)
grp_fireWater
# Out:
# (198, 3)
#                               Name Main Type  Sub Type
# 4                       Charmander      Fire       NaN
# 5                       Charmeleon      Fire       NaN
# 6                        Charizard      Fire    Flying
# 7     Charizard (Mega Charizard X)      Fire    Dragon
# 8     Charizard (Mega Charizard Y)      Fire    Flying
# 42                       Nidoqueen      Fire       NaN
# 43                        Nidoran♂      Fire       NaN
# 63                         Diglett      Fire       NaN
# 64        Diglett (Alolan Diglett)      Fire       NaN
# 83                        Alakazam      Fire       NaN
# 84        Alakazam (Mega Alakazam)      Fire       NaN
# 135                        Marowak      Fire       NaN
# 147                     Kangaskhan      Fire       NaN
# 158                           Jynx      Fire    Flying
# 169                          Eevee      Fire       NaN
# 170          Eevee (Partner Eevee)      Fire       NaN
# ...

# %%
search1 = pkm_df2[(pkm_df2['Main Type'] == 'Fire')&
                 (pkm_df2['Sub Type'] == 'Flying')]
print(search1.shape)
search1
# Out:
# (7, 3)
#                              Name Main Type Sub Type
# 6                       Charizard      Fire   Flying
# 8    Charizard (Mega Charizard Y)      Fire   Flying
# 158                          Jynx      Fire   Flying
# 270                      Delibird      Fire   Flying
# 730                     Hydreigon      Fire   Flying
# 731                      Larvesta      Fire   Flying
# 819        Gourgeist (Large Size)      Fire   Flying
